# %%
# !pip install pandas web3
# Out:
# Requirement already satisfied: pandas in c:\users\buboy\anaconda3\lib\site-packages (2.2.3)
# Collecting web3
#   Using cached web3-7.16.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\buboy\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\buboy\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\buboy\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\buboy\anaconda3\lib\site-packages (from pandas) (2025.2)
# Collecting eth-abi>=5.0.1 (from web3)
#   Using cached eth_abi-5.2.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting eth-account>=0.13.6 (from web3)
#   Using cached eth_account-0.13.7-py3-none-any.whl.metadata (3.7 kB)
# Collecting eth-hash>=0.5.1 (from eth-hash[pycryptodome]>=0.5.1->web3)
#   Using cached eth_hash-0.8.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting eth-typing>=5.0.0 (from web3)
#   Using cached eth_typing-6.0.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting eth-utils>=5.0.0 (from web3)
#   Using cached eth_utils-6.0.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting hexbytes>=1.2.0 (from web3)
#   Using cached hexbytes-1.3.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: aiohttp>=3.7.4.post0 in c:\users\buboy\anaconda3\lib\site-packages (from web3) (3.11.10)
# Requirement already satisfied: pydantic>=2.4.0 in c:\users\buboy\anaconda3\lib\site-packages (from web3) (2.10.3)
# Requirement already satisfied: pywin32>=223 in c:\users\buboy\anaconda3\lib\site-packages (from web3) (308)
# Requirement already satisfied: requests>=2.23.0 in c:\users\buboy\anaconda3\lib\site-packages (from web3) (2.32.3)
# Requirement already satisfied: typing-extensions>=4.0.1 in c:\users\buboy\anaconda3\lib\site-packages (from web3) (4.12.2)
# Collecting types-requests>=2.0.0 (from web3)
#   Using cached types_requests-2.33.0.20260518-py3-none-any.whl.metadata (2.2 kB)
# Collecting websockets<16.0.0,>=10.0.0 (from web3)
#   Downloading websockets-15.0.1-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Collecting pyunormalize>=15.0.0 (from web3)
#   Using cached pyunormalize-17.0.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\buboy\anaconda3\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\buboy\anaconda3\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\buboy\anaconda3\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\buboy\anaconda3\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\buboy\anaconda3\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\buboy\anaconda3\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\buboy\anaconda3\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (1.18.0)
# Requirement already satisfied: idna>=2.0 in c:\users\buboy\anaconda3\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.7.4.post0->web3) (3.7)
# Collecting parsimonious<0.11.0,>=0.10.0 (from eth-abi>=5.0.1->web3)
#   Using cached parsimonious-0.10.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: regex>=2022.3.15 in c:\users\buboy\anaconda3\lib\site-packages (from parsimonious<0.11.0,>=0.10.0->eth-abi>=5.0.1->web3) (2024.11.6)
# Collecting bitarray>=2.4.0 (from eth-account>=0.13.6->web3)
#   Downloading bitarray-3.8.1-cp313-cp313-win_amd64.whl.metadata (35 kB)
# Collecting eth-abi>=5.0.1 (from web3)
#   Using cached eth_abi-6.0.0b1-py3-none-any.whl.metadata (3.8 kB)
# Collecting eth-keyfile<0.9.0,>=0.7.0 (from eth-account>=0.13.6->web3)
#   Using cached eth_keyfile-0.8.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting eth-keys>=0.4.0 (from eth-account>=0.13.6->web3)
#   Using cached eth_keys-0.7.0-py3-none-any.whl.metadata (13 kB)
# Collecting eth-rlp>=2.1.0 (from eth-account>=0.13.6->web3)
#   Using cached eth_rlp-2.2.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting rlp>=1.0.0 (from eth-account>=0.13.6->web3)
#   Using cached rlp-4.1.0-py3-none-any.whl.metadata (3.2 kB)
# Collecting ckzg>=2.0.0 (from eth-account>=0.13.6->web3)
#   Downloading ckzg-2.1.7-cp313-cp313-win_amd64.whl.metadata (930 bytes)
# Collecting pycryptodome<4,>=3.6.6 (from eth-keyfile<0.9.0,>=0.7.0->eth-account>=0.13.6->web3)
#   Using cached pycryptodome-3.23.0-cp37-abi3-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: cytoolz>=0.10.1 in c:\users\buboy\anaconda3\lib\site-packages (from eth-utils>=5.0.0->web3) (1.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\buboy\anaconda3\lib\site-packages (from pydantic>=2.4.0->web3) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\buboy\anaconda3\lib\site-packages (from pydantic>=2.4.0->web3) (2.27.1)
# Requirement already satisfied: toolz>=0.8.0 in c:\users\buboy\anaconda3\lib\site-packages (from cytoolz>=0.10.1->eth-utils>=5.0.0->web3) (1.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\buboy\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\buboy\anaconda3\lib\site-packages (from requests>=2.23.0->web3) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\buboy\anaconda3\lib\site-packages (from requests>=2.23.0->web3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\buboy\anaconda3\lib\site-packages (from requests>=2.23.0->web3) (2025.8.3)
# Using cached web3-7.16.0-py3-none-any.whl (1.4 MB)
# Downloading websockets-15.0.1-cp313-cp313-win_amd64.whl (176 kB)
# Using cached eth_abi-5.2.0-py3-none-any.whl (28 kB)
# Using cached parsimonious-0.10.0-py3-none-any.whl (48 kB)
# Using cached eth_account-0.13.7-py3-none-any.whl (587 kB)
# Using cached eth_keyfile-0.8.1-py3-none-any.whl (7.5 kB)
# Using cached pycryptodome-3.23.0-cp37-abi3-win_amd64.whl (1.8 MB)
# Downloading bitarray-3.8.1-cp313-cp313-win_amd64.whl (150 kB)
# Downloading ckzg-2.1.7-cp313-cp313-win_amd64.whl (99 kB)
# Using cached eth_hash-0.8.0-py3-none-any.whl (8.0 kB)
# Using cached eth_keys-0.7.0-py3-none-any.whl (20 kB)
# Using cached eth_rlp-2.2.0-py3-none-any.whl (4.4 kB)
# Using cached eth_typing-6.0.0-py3-none-any.whl (19 kB)
# Using cached eth_utils-6.0.0-py3-none-any.whl (102 kB)
# Using cached hexbytes-1.3.1-py3-none-any.whl (5.1 kB)
# Using cached pyunormalize-17.0.0-py3-none-any.whl (51 kB)
# Using cached rlp-4.1.0-py3-none-any.whl (19 kB)
# Using cached types_requests-2.33.0.20260518-py3-none-any.whl (21 kB)
# Installing collected packages: ckzg, bitarray, websockets, types-requests, pyunormalize, pycryptodome, parsimonious, hexbytes, eth-typing, eth-hash, eth-utils, rlp, eth-keys, eth-abi, eth-rlp, eth-keyfile, eth-account, web3
#
#    -- -------------------------------------  1/18 [bitarray]
#    ---- -----------------------------------  2/18 [websockets]
#    ---- -----------------------------------  2/18 [websockets]
#    ---- -----------------------------------  2/18 [websockets]
#    ---- -----------------------------------  2/18 [websockets]
#    -------- -------------------------------  4/18 [pyunormalize]
#    ----------- ----------------------------  5/18 [pycryptodome]
#    ----------- ----------------------------  5/18 [pycryptodome]
#    ----------- ----------------------------  5/18 [pycryptodome]
#    ----------- ----------------------------  5/18 [pycryptodome]
#    ----------- ----------------------------  5/18 [pycryptodome]
#    ----------- ----------------------------  5/18 [pycryptodome]
#    ----------- ----------------------------  5/18 [pycryptodome]
#    ----------- ----------------------------  5/18 [pycryptodome]
#    ----------- ----------------------------  5/18 [pycryptodome]
#    ----------- ----------------------------  5/18 [pycryptodome]
#    ----------- ----------------------------  5/18 [pycryptodome]
#    ----------- ----------------------------  5/18 [pycryptodome]
#    ----------- ----------------------------  5/18 [pycryptodome]
#    ----------- ----------------------------  5/18 [pycryptodome]
#    ----------- ----------------------------  5/18 [pycryptodome]
#    --------------- ------------------------  7/18 [hexbytes]
#    -------------------- -------------------  9/18 [eth-hash]
#    ---------------------- ----------------- 10/18 [eth-utils]
#    ------------------------ --------------- 11/18 [rlp]
#    -------------------------- ------------- 12/18 [eth-keys]
#    ---------------------------- ----------- 13/18 [eth-abi]
#    ----------------------------------- ---- 16/18 [eth-account]
#    ----------------------------------- ---- 16/18 [eth-account]
#    ----------------------------------- ---- 16/18 [eth-account]
#    ------------------------------------- -- 17/18 [web3]
#    ------------------------------------- -- 17/18 [web3]
#    ------------------------------------- -- 17/18 [web3]
#    ------------------------------------- -- 17/18 [web3]
#    ------------------------------------- -- 17/18 [web3]
#    ------------------------------------- -- 17/18 [web3]
#    ------------------------------------- -- 17/18 [web3]
#    ------------------------------------- -- 17/18 [web3]
#    ------------------------------------- -- 17/18 [web3]
#    ------------------------------------- -- 17/18 [web3]
#    ------------------------------------- -- 17/18 [web3]
#    ---------------------------------------- 18/18 [web3]
#
# Successfully installed bitarray-3.8.1 ckzg-2.1.7 eth-abi-5.2.0 eth-account-0.13.7 eth-hash-0.8.0 eth-keyfile-0.8.1 eth-keys-0.7.0 eth-rlp-2.2.0 eth-typing-6.0.0 eth-utils-6.0.0 hexbytes-1.3.1 parsimonious-0.10.0 pycryptodome-3.23.0 pyunormalize-17.0.0 rlp-4.1.0 types-requests-2.33.0.20260518 web3-7.16.0 websockets-15.0.1

# %%
import pandas as pd
from web3 import Web3

# %%
csv_file = r"C:\Users\Buboy\Downloads\MO-IT148 Homework_ IoT Data Simulation H3101 TEAM CTRL+ALT+ELITE ADET EDITION.csv"

df = pd.read_csv(csv_file)

print("CSV loaded successfully!")
print("Number of CSV records:", len(df))
display(df.head())
# Out:
# CSV loaded successfully!
# Number of CSV records: 80
#    Event_ID       Shipment_ID            RFID_Tag            Timestamp  \
# 0         1  PH-DAV-2026-0001  9400E3233024854184  2026-05-09 20:45:00
# 1         2  PH-DAV-2026-0001  9400E3233024854184  2026-05-09 21:04:00
# 2         3  PH-DAV-2026-0001  9400E3233024854184  2026-05-09 21:39:00
# 3         4  PH-DAV-2026-0001  9400E3233024854184  2026-05-09 22:43:00
# 4         5  PH-DAV-2026-0002  9400E3536100814156  2026-05-09 20:45:00
#
#     Latitude   Longitude        Checkpoint Action_Type        Driver_Name  \
# 0  13.462483  123.262439  WAREHOUSE_PICKUP      PICKUP   Miguel Rodriguez
# 1  13.335912  123.301817         SLEX_TOLL   TOLL_PASS   Miguel Rodriguez
# 2  13.387291  123.305393    RIDER_HANDHELD      ASSIGN   Miguel Rodriguez
# 3  13.438701  123.171442     DOORSTEP_ePOD    DELIVERY   Miguel Rodriguez
# 4   9.803495  118.662055  WAREHOUSE_PICKUP      PICKUP  Antonio Fernandez
#
#   Vehicle_Plate  Temperature_C  Humidity_%  Shock_G-force  Battery_%  \
# 0      SUB-5678            6.8        59.4           0.33         80
# 1      SUB-5678           10.0        69.8           0.36         80
# 2      SUB-5678           10.2        59.8           0.67         78
# 3      SUB-5678            7.6        62.6           0.69         88
# 4      CDO-5432            6.2        45.1           0.76         92
#
#    Speed_kmh  Fuel_% Network_Signal  Toll_Amount_PHP  Duration_Min  \
# 0         60      65           NONE              NaN             0
# 1         15      95           GOOD              0.0            19
# 2         30      80           NONE              NaN            35
# 3         60      95           FAIR              NaN            64
# 4         70      65           WEAK              NaN             0
#
#       Anomaly_Flag
# 0  CONNECTION_LOST
# 1              NaN
# 2  CONNECTION_LOST
# 3              NaN
# 4              NaN

# %%
ganache_url = "http://127.0.0.1:7545"
web3 = Web3(Web3.HTTPProvider(ganache_url))

if web3.is_connected():
    print("Connected to Ganache successfully!")
else:
    print("Connection failed. Ensure Ganache is running.")
# Out:
# Connected to Ganache successfully!

# %%
contract_address = "0xAF5D8457982f15462235ADa59BF7a5d97a7D022C"

abi = [
    {
        "inputs": [],
        "name": "getTotalRecords",
        "outputs": [{"internalType": "uint256", "name": "", "type": "uint256"}],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [{"internalType": "uint256", "name": "index", "type": "uint256"}],
        "name": "getRecord",
        "outputs": [
            {"internalType": "uint256", "name": "timestamp", "type": "uint256"},
            {"internalType": "string", "name": "deviceId", "type": "string"},
            {"internalType": "string", "name": "dataType", "type": "string"},
            {"internalType": "string", "name": "dataValue", "type": "string"}
        ],
        "stateMutability": "view",
        "type": "function"
    }
]

contract = web3.eth.contract(address=contract_address, abi=abi)
web3.eth.default_account = web3.eth.accounts[0]

print("Connected to Smart Contract at:", contract_address)
print("Default sender:", web3.eth.default_account)

total_records = contract.functions.getTotalRecords().call()
print("Total records currently stored:", total_records)
# Out:
# Connected to Smart Contract at: 0xAF5D8457982f15462235ADa59BF7a5d97a7D022C
# Default sender: 0xA3A414De288481841Da8C48D99500b4f1ace36Eb
# Total records currently stored: 82

# %%
first_record = contract.functions.getRecord(0).call()

print("First Stored Record:")
print("Timestamp:", first_record[0])
print("Device ID:", first_record[1])
print("Data Type:", first_record[2])
print("Data Value:", first_record[3])
# Out:
# First Stored Record:
# Timestamp: 1780080086
# Device ID: PKG001
# Data Type: Location
# Data Value: Manila Warehouse

# %%
latest_record = contract.functions.getRecord(total_records - 1).call()

print("Latest Stored Record:")
print("Timestamp:", latest_record[0])
print("Device ID:", latest_record[1])
print("Data Type:", latest_record[2])
print("Data Value:", latest_record[3])
# Out:
# Latest Stored Record:
# Timestamp: 1780083547
# Device ID: PH-MAN-2026-0020
# Data Type: Smart Logistics Tracking
# Data Value: Event 80 | Checkpoint: DOORSTEP_ePOD | Status: DELIVERY | Location: 14.62198, 121.047597 | Temp: 6.0 C | Humidity: 74.6% | Shock: 0.21 G | Battery: 83% | Signal: EXCELLENT | Anomaly: NORMAL
